# %%
import re
import time
import json
import requests
import pandas as pd
from docx import Document

from rapidfuzz import fuzz
from dateutil import parser as dateparser

import fitz  # PyMuPDF

import importlib
import extractors.acs_pdf as acs_pdf
importlib.reload(acs_pdf)

from extractors.acs_pdf import extract_references_from_acs_pdf
from report.acs_report import build_acs_report, PigThresholds
from journal_title.journal_iso4 import best_journal_score, add_iso4_columns
from journal_title.journal_from_raw import extract_journal_from_acs_raw, clean_journal_obs

# %%
# ---- User input / run metadata ----
ARTICLE_TITLE = input("Enter the article title under evaluation:\n").strip()

if not ARTICLE_TITLE:
    raise ValueError("Article title is required.")
# Out:
# Enter the article title under evaluation:
#  Visualizing Spatial Distribution of Poly(n‑Alkyl Acrylates) Aggregates in Pressure Sensitive Adhesive Films

# %%
df_original, report = extract_references_from_acs_pdf("test.pdf", expected_n=55)

# %%
DOI_RE = re.compile(r"(10\.\d{4,9}/[^\s\"\'<>]+)", re.IGNORECASE)

def extract_doi_from_raw(raw: str):
    if not isinstance(raw, str):
        return None
    m = DOI_RE.search(raw)
    if not m:
        return None
    return m.group(1).rstrip(").,;]}")

# %%
df_original["doi_raw"] = df_original["raw"].apply(extract_doi_from_raw)
df_original["doi_status"] = df_original["doi_raw"].apply(
    lambda d: "OK" if d else "No DOI"
)

df_original["doi_url"] = df_original["doi_raw"].apply(
    lambda d: f"https://doi.org/{d}" if d else None
)

# %%
df_original
# Out:
#     ref_id                                                raw doi_raw  \
# 0        1  Xiang, M.; Lyu, D.; Qin, Y.; Chen, R.; Liu, L....    None
# 1        2  Zhang, Z.; Chen, M.; Schneider, I.; Liu, Y.; L...    None
# 2        3  Hempel, E.; Budde, H.; Höring, S.; Beiner, M. ...    None
# 3        4  Hyun, J.; Ma, H.; Banerjee, P.; Cole, J.; Gons...    None
# 4        5  Zhang, M.; Estournès, C.; Bietsch, W.; Mülle...    None
# 5        6  Miyake, G. M.; Weitekamp, R. A.; Piunova, V. A...    None
# 6        7  Runge, M. B.; Bowden, N. B. Synthesis of High ...    None
# 7        8  Yuan, J.; Xu, Y.; Walther, A.; Bolisetty, S.; ...    None
# 8        9  Lee, J.; Kwak, G. Extremely Softened Polyimide...    None
# 9       10  Zhou, J.; Turner, S. A.; Brosnan, S. M.; Li, Q...    None
# 10      11  Bandl, C.; Kern, W.; Schlögl, S. Adhesives for...    None
# 11      12  Yin, Q.; Manav, Y. A.; Wan, Y.; Davaji, B.; Ba...    None
# 12      13  Tan, D.; Xu, B.; Chung, K. Y.; Yang, Y.; Wang,...    None
# 13      14  Swanson, S.; Bashmail, R.; Fellin, C.; Luu, V....    None
# 14      15  Liu, R.; Swanson, S.; Huang, E.; Krejsa, M. R....    None
# 15      16  Fumarola, S.; Allaway, R.; Callaghan, R.; Coll...    None
# 16      17  Swanson, S.; Luu, V.; Smith, R.; Gross, A.; Tu...    None
# 17      18  Mess, A.; Vietzke, J.-P.; Rapp, C.; Francke, W...    None
# 18      19  Doi, T.; Takagi, H.; Shimizu, N.; Igarashi, N....    None
# 19      20  Fernando, S.; Bhatia, S. R. Scalable Manufactu...    None
# 20      21  Nwaneshiudu, A.; Kuschal, C.; Sakamoto, F. H.;...    None
# 21      22  St. Croix, C. M.; Shand, S. H.; Watkins, S. C....    None
# 22      23  Paddock, S. W. Principles and Practices of Las...    None
# 23      24  Kwon, J.; Jun, S. W.; Choi, S. I.; Mao, X.; Ki...    None
# 24      25  Cauzzo, S.; Bruno, E.; Boulet, D.; Nazac, P.; ...    None
# 25      26  Zhu, Y.; Hou, J.; Gray, D. M.; McDonald, T. O....    None
# 26      27  Icha, J.; Böning, D.; Türschmann, P. Precise ...    None
# 27      28  Helmchen, F.; Denk, W. Deep Tissue Two-Photon ...    None
# 28      29  Yang, X.; Jiang, Z.; Dai, J.; Fu, Q.; Pan, S. ...    None
# 29      30  Miki, K.; Kimura, A.; Oride, K.; Kuramochi, Y....    None
# 30      31  Miki, K.; Oride, K.; Kimura, A.; Kuramochi, Y....    None
# 31      32  Hans Tromp, R.; Van De Velde, F.; Van Riel, J....    None
# 32      33  Reisch, A.; Klymchenko, A. S. Fluorescent Poly...    None
# 33      34  Chaudhuri, K.; Medhi, R.; Zhang, Z.; Cai, Z.; ...    None
# 34      35  Nile, R.; Feng, S.; Cabello, M.; Wang, D.; Yan...    None
# 35      36  Ismael, R.; Schwander, H.; Hendrix, P. Fluores...    None
# 36      37  Usowicz, M. T.; Kelley, M. J.; Singer, K. D.; ...    None
# 37      38  Duarte, F.; Morice, K.; Ghanem, T.; Puchán Sán...    None
# 38      39  Lim, S. D.; Svanevik, C. C.; Fauver, M. E.; Ne...    None
# 39      40  Petersson, M.; Gustafson, I.; Stading, M. Agei...    None
# 40      41  Haj-Shafiei, S.; Workman, B.; Trifkovic, M.; M...    None
# 41      42  Creton, C.; Ciccotti, M. Fracture and Adhesion...    None
# 42      43  Gent, A. N. Adhesion and Strength of Viscoelas...    None
# 43      44  Gent, A. N.; Schultz, J. Effect of Wetting Liq...    None
# 44      45  Maugis, D.; Barquins, M. Fracture Mechanics an...    None
# 45      46  Villey, R.; Creton, C.; Cortet, P.-P.; Dalbe, ...    None
# 46      47  Villey, R.; Cortet, P.-P.; Creton, C.; Ciccott...    None
# 47      48  Beiner, M.; Huth, H. Nanophase Separation and ...    None
# 48      49  Xia, W.; Song, J.; Hsu, D. D.; Keten, S. Under...    None
# 49      50  Dokukin, M. E.; Sokolov, I. On the Measurement...    None
# 50      51  Jackson, C. L.; Chanzy, H. D.; Booy, F. P.; Dr...    None
# 51      52  Jinnai, H.; Spontak, R. J.; Nishi, T. Transmis...    None
# 52      53  Korpanty, J.; Parent, L. R.; Hampu, N.; Weigan...    None
# 53      54  Prakash, K.; Diederich, B.; Heintzmann, R.; Sc...    None
# 54      55  Yusoh, N. A.; Gill, M. R.; Tian, X. Advancing ...    None
#
#    doi_status doi_url
# 0      No DOI    None
# 1      No DOI    None
# 2      No DOI    None
# 3      No DOI    None
# 4      No DOI    None
# 5      No DOI    None
# 6      No DOI    None
# 7      No DOI    None
# 8      No DOI    None
# 9      No DOI    None
# 10     No DOI    None
# 11     No DOI    None
# 12     No DOI    None
# 13     No DOI    None
# 14     No DOI    None
# 15     No DOI    None
# 16     No DOI    None
# 17     No DOI    None
# 18     No DOI    None
# 19     No DOI    None
# 20     No DOI    None
# 21     No DOI    None
# 22     No DOI    None
# 23     No DOI    None
# 24     No DOI    None
# 25     No DOI    None
# 26     No DOI    None
# 27     No DOI    None
# 28     No DOI    None
# 29     No DOI    None
# 30     No DOI    None
# 31     No DOI    None
# 32     No DOI    None
# 33     No DOI    None
# 34     No DOI    None
# 35     No DOI    None
# 36     No DOI    None
# 37     No DOI    None
# 38     No DOI    None
# 39     No DOI    None
# 40     No DOI    None
# 41     No DOI    None
# 42     No DOI    None
# 43     No DOI    None
# 44     No DOI    None
# 45     No DOI    None
# 46     No DOI    None
# 47     No DOI    None
# 48     No DOI    None
# 49     No DOI    None
# 50     No DOI    None
# 51     No DOI    None
# 52     No DOI    None
# 53     No DOI    None
# 54     No DOI    None

# %%
def normalize_doi(doi: str):
    if not isinstance(doi, str) or not doi.strip():
        return None
    doi = doi.strip()
    doi = doi.replace("https://doi.org/", "").replace("http://doi.org/", "")
    doi = doi.replace("doi:", "").strip()
    doi = doi.rstrip(").,;]}")
    return doi.lower()

def crossref_find_doi_from_citation(raw: str, timeout=20):
    if not raw:
        return None

    url = "https://api.crossref.org/works"
    params = {"query.bibliographic": raw, "rows": 3}
    headers = {"User-Agent": "kilbreths-pig/0.1 (mailto:YOUR_EMAIL_HERE)"}  # put your email

    r = requests.get(url, params=params, headers=headers, timeout=timeout)
    if r.status_code != 200:
        return None

    items = (r.json().get("message", {}) or {}).get("items", []) or []
    for it in items:
        doi = it.get("DOI")
        if doi:
            return normalize_doi(doi)
    return None

def openalex_find_doi_from_citation(raw: str, timeout=20):
    if not raw:
        return None

    url = "https://api.openalex.org/works"
    params = {"search": raw, "per-page": 3}
    headers = {"User-Agent": "kilbreths-pig/0.1"}

    r = requests.get(url, params=params, headers=headers, timeout=timeout)
    if r.status_code != 200:
        return None

    results = r.json().get("results", []) or []
    for it in results:
        doi = it.get("doi")
        if doi:
            return normalize_doi(doi)
    return None

def fill_missing_dois(df, sleep_s=0.2):
    df = df.copy()

    doi_found = []
    doi_source = []

    for _, row in df.iterrows():
        raw = row.get("raw", "") or ""

        doi = crossref_find_doi_from_citation(raw)
        src = "crossref" if doi else None

        if not doi:
            doi = openalex_find_doi_from_citation(raw)
            src = "openalex" if doi else None

        doi_found.append(doi)
        doi_source.append(src or "none")
        time.sleep(sleep_s)

    df["doi_found"] = doi_found
    df["doi_source"] = doi_source
    df["doi_final"] = df["doi_found"].apply(normalize_doi)
    df["doi_status"] = df["doi_final"].apply(lambda d: "OK" if d else "No DOI")
    df["doi_url_final"] = df["doi_final"].apply(lambda d: f"https://doi.org/{d}" if d else None)

    return df

# Run it:
# df_original = fill_missing_dois(df_original, sleep_s=0.25)
# df_original["doi_status"].value_counts()

# %%
df_original
# Out:
#     ref_id                                                raw doi_raw  \
# 0        1  Xiang, M.; Lyu, D.; Qin, Y.; Chen, R.; Liu, L....    None
# 1        2  Zhang, Z.; Chen, M.; Schneider, I.; Liu, Y.; L...    None
# 2        3  Hempel, E.; Budde, H.; Höring, S.; Beiner, M. ...    None
# 3        4  Hyun, J.; Ma, H.; Banerjee, P.; Cole, J.; Gons...    None
# 4        5  Zhang, M.; Estournès, C.; Bietsch, W.; Mülle...    None
# 5        6  Miyake, G. M.; Weitekamp, R. A.; Piunova, V. A...    None
# 6        7  Runge, M. B.; Bowden, N. B. Synthesis of High ...    None
# 7        8  Yuan, J.; Xu, Y.; Walther, A.; Bolisetty, S.; ...    None
# 8        9  Lee, J.; Kwak, G. Extremely Softened Polyimide...    None
# 9       10  Zhou, J.; Turner, S. A.; Brosnan, S. M.; Li, Q...    None
# 10      11  Bandl, C.; Kern, W.; Schlögl, S. Adhesives for...    None
# 11      12  Yin, Q.; Manav, Y. A.; Wan, Y.; Davaji, B.; Ba...    None
# 12      13  Tan, D.; Xu, B.; Chung, K. Y.; Yang, Y.; Wang,...    None
# 13      14  Swanson, S.; Bashmail, R.; Fellin, C.; Luu, V....    None
# 14      15  Liu, R.; Swanson, S.; Huang, E.; Krejsa, M. R....    None
# 15      16  Fumarola, S.; Allaway, R.; Callaghan, R.; Coll...    None
# 16      17  Swanson, S.; Luu, V.; Smith, R.; Gross, A.; Tu...    None
# 17      18  Mess, A.; Vietzke, J.-P.; Rapp, C.; Francke, W...    None
# 18      19  Doi, T.; Takagi, H.; Shimizu, N.; Igarashi, N....    None
# 19      20  Fernando, S.; Bhatia, S. R. Scalable Manufactu...    None
# 20      21  Nwaneshiudu, A.; Kuschal, C.; Sakamoto, F. H.;...    None
# 21      22  St. Croix, C. M.; Shand, S. H.; Watkins, S. C....    None
# 22      23  Paddock, S. W. Principles and Practices of Las...    None
# 23      24  Kwon, J.; Jun, S. W.; Choi, S. I.; Mao, X.; Ki...    None
# 24      25  Cauzzo, S.; Bruno, E.; Boulet, D.; Nazac, P.; ...    None
# 25      26  Zhu, Y.; Hou, J.; Gray, D. M.; McDonald, T. O....    None
# 26      27  Icha, J.; Böning, D.; Türschmann, P. Precise ...    None
# 27      28  Helmchen, F.; Denk, W. Deep Tissue Two-Photon ...    None
# 28      29  Yang, X.; Jiang, Z.; Dai, J.; Fu, Q.; Pan, S. ...    None
# 29      30  Miki, K.; Kimura, A.; Oride, K.; Kuramochi, Y....    None
# 30      31  Miki, K.; Oride, K.; Kimura, A.; Kuramochi, Y....    None
# 31      32  Hans Tromp, R.; Van De Velde, F.; Van Riel, J....    None
# 32      33  Reisch, A.; Klymchenko, A. S. Fluorescent Poly...    None
# 33      34  Chaudhuri, K.; Medhi, R.; Zhang, Z.; Cai, Z.; ...    None
# 34      35  Nile, R.; Feng, S.; Cabello, M.; Wang, D.; Yan...    None
# 35      36  Ismael, R.; Schwander, H.; Hendrix, P. Fluores...    None
# 36      37  Usowicz, M. T.; Kelley, M. J.; Singer, K. D.; ...    None
# 37      38  Duarte, F.; Morice, K.; Ghanem, T.; Puchán Sán...    None
# 38      39  Lim, S. D.; Svanevik, C. C.; Fauver, M. E.; Ne...    None
# 39      40  Petersson, M.; Gustafson, I.; Stading, M. Agei...    None
# 40      41  Haj-Shafiei, S.; Workman, B.; Trifkovic, M.; M...    None
# 41      42  Creton, C.; Ciccotti, M. Fracture and Adhesion...    None
# 42      43  Gent, A. N. Adhesion and Strength of Viscoelas...    None
# 43      44  Gent, A. N.; Schultz, J. Effect of Wetting Liq...    None
# 44      45  Maugis, D.; Barquins, M. Fracture Mechanics an...    None
# 45      46  Villey, R.; Creton, C.; Cortet, P.-P.; Dalbe, ...    None
# 46      47  Villey, R.; Cortet, P.-P.; Creton, C.; Ciccott...    None
# 47      48  Beiner, M.; Huth, H. Nanophase Separation and ...    None
# 48      49  Xia, W.; Song, J.; Hsu, D. D.; Keten, S. Under...    None
# 49      50  Dokukin, M. E.; Sokolov, I. On the Measurement...    None
# 50      51  Jackson, C. L.; Chanzy, H. D.; Booy, F. P.; Dr...    None
# 51      52  Jinnai, H.; Spontak, R. J.; Nishi, T. Transmis...    None
# 52      53  Korpanty, J.; Parent, L. R.; Hampu, N.; Weigan...    None
# 53      54  Prakash, K.; Diederich, B.; Heintzmann, R.; Sc...    None
# 54      55  Yusoh, N. A.; Gill, M. R.; Tian, X. Advancing ...    None
#
#    doi_status doi_url
# 0      No DOI    None
# 1      No DOI    None
# 2      No DOI    None
# 3      No DOI    None
# 4      No DOI    None
# 5      No DOI    None
# 6      No DOI    None
# 7      No DOI    None
# 8      No DOI    None
# 9      No DOI    None
# 10     No DOI    None
# 11     No DOI    None
# 12     No DOI    None
# 13     No DOI    None
# 14     No DOI    None
# 15     No DOI    None
# 16     No DOI    None
# 17     No DOI    None
# 18     No DOI    None
# 19     No DOI    None
# 20     No DOI    None
# 21     No DOI    None
# 22     No DOI    None
# 23     No DOI    None
# 24     No DOI    None
# 25     No DOI    None
# 26     No DOI    None
# 27     No DOI    None
# 28     No DOI    None
# 29     No DOI    None
# 30     No DOI    None
# 31     No DOI    None
# 32     No DOI    None
# 33     No DOI    None
# 34     No DOI    None
# 35     No DOI    None
# 36     No DOI    None
# 37     No DOI    None
# 38     No DOI    None
# 39     No DOI    None
# 40     No DOI    None
# 41     No DOI    None
# 42     No DOI    None
# 43     No DOI    None
# 44     No DOI    None
# 45     No DOI    None
# 46     No DOI    None
# 47     No DOI    None
# 48     No DOI    None
# 49     No DOI    None
# 50     No DOI    None
# 51     No DOI    None
# 52     No DOI    None
# 53     No DOI    None
# 54     No DOI    None

# %%
df_original = fill_missing_dois(df_original, sleep_s=0.25)

# %%
df_original
# Out:
#     ref_id                                                raw doi_raw  \
# 0        1  Xiang, M.; Lyu, D.; Qin, Y.; Chen, R.; Liu, L....    None
# 1        2  Zhang, Z.; Chen, M.; Schneider, I.; Liu, Y.; L...    None
# 2        3  Hempel, E.; Budde, H.; Höring, S.; Beiner, M. ...    None
# 3        4  Hyun, J.; Ma, H.; Banerjee, P.; Cole, J.; Gons...    None
# 4        5  Zhang, M.; Estournès, C.; Bietsch, W.; Mülle...    None
# 5        6  Miyake, G. M.; Weitekamp, R. A.; Piunova, V. A...    None
# 6        7  Runge, M. B.; Bowden, N. B. Synthesis of High ...    None
# 7        8  Yuan, J.; Xu, Y.; Walther, A.; Bolisetty, S.; ...    None
# 8        9  Lee, J.; Kwak, G. Extremely Softened Polyimide...    None
# 9       10  Zhou, J.; Turner, S. A.; Brosnan, S. M.; Li, Q...    None
# 10      11  Bandl, C.; Kern, W.; Schlögl, S. Adhesives for...    None
# 11      12  Yin, Q.; Manav, Y. A.; Wan, Y.; Davaji, B.; Ba...    None
# 12      13  Tan, D.; Xu, B.; Chung, K. Y.; Yang, Y.; Wang,...    None
# 13      14  Swanson, S.; Bashmail, R.; Fellin, C.; Luu, V....    None
# 14      15  Liu, R.; Swanson, S.; Huang, E.; Krejsa, M. R....    None
# 15      16  Fumarola, S.; Allaway, R.; Callaghan, R.; Coll...    None
# 16      17  Swanson, S.; Luu, V.; Smith, R.; Gross, A.; Tu...    None
# 17      18  Mess, A.; Vietzke, J.-P.; Rapp, C.; Francke, W...    None
# 18      19  Doi, T.; Takagi, H.; Shimizu, N.; Igarashi, N....    None
# 19      20  Fernando, S.; Bhatia, S. R. Scalable Manufactu...    None
# 20      21  Nwaneshiudu, A.; Kuschal, C.; Sakamoto, F. H.;...    None
# 21      22  St. Croix, C. M.; Shand, S. H.; Watkins, S. C....    None
# 22      23  Paddock, S. W. Principles and Practices of Las...    None
# 23      24  Kwon, J.; Jun, S. W.; Choi, S. I.; Mao, X.; Ki...    None
# 24      25  Cauzzo, S.; Bruno, E.; Boulet, D.; Nazac, P.; ...    None
# 25      26  Zhu, Y.; Hou, J.; Gray, D. M.; McDonald, T. O....    None
# 26      27  Icha, J.; Böning, D.; Türschmann, P. Precise ...    None
# 27      28  Helmchen, F.; Denk, W. Deep Tissue Two-Photon ...    None
# 28      29  Yang, X.; Jiang, Z.; Dai, J.; Fu, Q.; Pan, S. ...    None
# 29      30  Miki, K.; Kimura, A.; Oride, K.; Kuramochi, Y....    None
# 30      31  Miki, K.; Oride, K.; Kimura, A.; Kuramochi, Y....    None
# 31      32  Hans Tromp, R.; Van De Velde, F.; Van Riel, J....    None
# 32      33  Reisch, A.; Klymchenko, A. S. Fluorescent Poly...    None
# 33      34  Chaudhuri, K.; Medhi, R.; Zhang, Z.; Cai, Z.; ...    None
# 34      35  Nile, R.; Feng, S.; Cabello, M.; Wang, D.; Yan...    None
# 35      36  Ismael, R.; Schwander, H.; Hendrix, P. Fluores...    None
# 36      37  Usowicz, M. T.; Kelley, M. J.; Singer, K. D.; ...    None
# 37      38  Duarte, F.; Morice, K.; Ghanem, T.; Puchán Sán...    None
# 38      39  Lim, S. D.; Svanevik, C. C.; Fauver, M. E.; Ne...    None
# 39      40  Petersson, M.; Gustafson, I.; Stading, M. Agei...    None
# 40      41  Haj-Shafiei, S.; Workman, B.; Trifkovic, M.; M...    None
# 41      42  Creton, C.; Ciccotti, M. Fracture and Adhesion...    None
# 42      43  Gent, A. N. Adhesion and Strength of Viscoelas...    None
# 43      44  Gent, A. N.; Schultz, J. Effect of Wetting Liq...    None
# 44      45  Maugis, D.; Barquins, M. Fracture Mechanics an...    None
# 45      46  Villey, R.; Creton, C.; Cortet, P.-P.; Dalbe, ...    None
# 46      47  Villey, R.; Cortet, P.-P.; Creton, C.; Ciccott...    None
# 47      48  Beiner, M.; Huth, H. Nanophase Separation and ...    None
# 48      49  Xia, W.; Song, J.; Hsu, D. D.; Keten, S. Under...    None
# 49      50  Dokukin, M. E.; Sokolov, I. On the Measurement...    None
# 50      51  Jackson, C. L.; Chanzy, H. D.; Booy, F. P.; Dr...    None
# 51      52  Jinnai, H.; Spontak, R. J.; Nishi, T. Transmis...    None
# 52      53  Korpanty, J.; Parent, L. R.; Hampu, N.; Weigan...    None
# 53      54  Prakash, K.; Diederich, B.; Heintzmann, R.; Sc...    None
# 54      55  Yusoh, N. A.; Gill, M. R.; Tian, X. Advancing ...    None
#
#    doi_status doi_url                         doi_found doi_source  \
# 0          OK    None     10.1016/j.polymer.2020.123034   crossref
# 1          OK    None      10.1021/acs.macromol.0c01784   crossref
# 2          OK    None  10.1016/j.jnoncrysol.2006.01.131   crossref
# 3          OK    None                 10.1021/la015712x   crossref
# 4          OK    None            10.1002/adfm.200400064   crossref
# 5          OK    None                 10.1021/ja306430k   crossref
# 6          OK    None                 10.1021/ja072929q   crossref
# 7          OK    None                  10.1038/nmat2232   crossref
# 8          OK    None            10.1021/acsapm.5c01168   crossref
# 9          OK    None                 10.1021/ma4023185   crossref
# 10         OK    None    10.1016/j.ijadhadh.2020.102585   crossref
# 11         OK    None         10.1016/j.eml.2025.102293   crossref
# 12         OK    None            10.1002/adfm.202311457   crossref
# 13         OK    None              10.3390/ijms23137164   crossref
# 14         OK    None                 10.1115/1.4068595   crossref
# 15         OK    None    10.12968/jowc.2020.29.sup3c.s1   crossref
# 16         OK    None      10.12968/jowc.2023.32.10.665   crossref
# 17         OK    None                 10.1021/ac2011608   crossref
# 18         OK    None     10.1016/j.polymer.2019.02.052   crossref
# 19         OK    None      10.1016/j.colcom.2025.100837   crossref
# 20         OK    None              10.1038/jid.2012.429   crossref
# 21         OK    None                 10.2144/000112089   crossref
# 22         OK    None               10.1385/mb:16:2:127   crossref
# 23         OK    None            10.1126/sciadv.aay0044   crossref
# 24         OK    None        10.1038/s41467-024-48146-y   crossref
# 25         OK    None     10.1016/j.heliyon.2024.e32184   crossref
# 26         OK    None         10.1017/s1551929521001553   crossref
# 27         OK    None                  10.1038/nmeth818   crossref
# 28         OK    None                10.1039/d4nh00395k   crossref
# 29         OK    None            10.1002/anie.201101005   crossref
# 30         OK    None            10.1002/smll.201101637   crossref
# 31         OK    None     10.1016/s0963-9969(01)00117-x   crossref
# 32         OK    None            10.1002/smll.201503396   crossref
# 33         OK    None            10.1002/marc.202300304   crossref
# 34         OK    None            10.1002/macp.202300230   crossref
# 35         OK    None     10.1002/14356007.a11_279.pub2   crossref
# 36         OK    None                 10.1021/jp203703e   crossref
# 37         OK    None      10.1016/j.molliq.2024.125424   crossref
# 38         OK    None                 10.1115/1.4045298   crossref
# 39         OK    None         10.1007/s10853-007-2416-x   crossref
# 40         OK    None           10.1021/acs.cgd.9b00052   crossref
# 41         OK    None     10.1088/0034-4885/79/4/046601   crossref
# 42         OK    None                 10.1021/la950887q   crossref
# 43         OK    None         10.1080/00218467208072199   crossref
# 44         OK    None       10.1088/0022-3727/11/14/011   crossref
# 45         OK    None                10.1039/c5sm00260e   crossref
# 46         OK    None         10.1007/s10704-016-0171-1   crossref
# 47         OK    None                   10.1038/nmat966   crossref
# 48         OK    None      10.1021/acs.macromol.6b00121   crossref
# 49         OK    None                 10.1021/ma202600b   crossref
# 50         OK    None                 10.1021/ma9806155   crossref
# 51         OK    None                 10.1021/ma902035p   crossref
# 52         OK    None        10.1038/s41467-021-26773-z   crossref
# 53         OK    None            10.1098/rsta.2021.0110   crossref
# 54         OK    None                10.1039/d4cs01193g   crossref
#
#                            doi_final  \
# 0      10.1016/j.polymer.2020.123034
# 1       10.1021/acs.macromol.0c01784
# 2   10.1016/j.jnoncrysol.2006.01.131
# 3                  10.1021/la015712x
# 4             10.1002/adfm.200400064
# 5                  10.1021/ja306430k
# 6                  10.1021/ja072929q
# 7                   10.1038/nmat2232
# 8             10.1021/acsapm.5c01168
# 9                  10.1021/ma4023185
# 10    10.1016/j.ijadhadh.2020.102585
# 11         10.1016/j.eml.2025.102293
# 12            10.1002/adfm.202311457
# 13              10.3390/ijms23137164
# 14                 10.1115/1.4068595
# 15    10.12968/jowc.2020.29.sup3c.s1
# 16      10.12968/jowc.2023.32.10.665
# 17                 10.1021/ac2011608
# 18     10.1016/j.polymer.2019.02.052
# 19      10.1016/j.colcom.2025.100837
# 20              10.1038/jid.2012.429
# 21                 10.2144/000112089
# 22               10.1385/mb:16:2:127
# 23            10.1126/sciadv.aay0044
# 24        10.1038/s41467-024-48146-y
# 25     10.1016/j.heliyon.2024.e32184
# 26         10.1017/s1551929521001553
# 27                  10.1038/nmeth818
# 28                10.1039/d4nh00395k
# 29            10.1002/anie.201101005
# 30            10.1002/smll.201101637
# 31     10.1016/s0963-9969(01)00117-x
# 32            10.1002/smll.201503396
# 33            10.1002/marc.202300304
# 34            10.1002/macp.202300230
# 35     10.1002/14356007.a11_279.pub2
# 36                 10.1021/jp203703e
# 37      10.1016/j.molliq.2024.125424
# 38                 10.1115/1.4045298
# 39         10.1007/s10853-007-2416-x
# 40           10.1021/acs.cgd.9b00052
# 41     10.1088/0034-4885/79/4/046601
# 42                 10.1021/la950887q
# 43         10.1080/00218467208072199
# 44       10.1088/0022-3727/11/14/011
# 45                10.1039/c5sm00260e
# 46         10.1007/s10704-016-0171-1
# 47                   10.1038/nmat966
# 48      10.1021/acs.macromol.6b00121
# 49                 10.1021/ma202600b
# 50                 10.1021/ma9806155
# 51                 10.1021/ma902035p
# 52        10.1038/s41467-021-26773-z
# 53            10.1098/rsta.2021.0110
# 54                10.1039/d4cs01193g
#
#                                        doi_url_final
# 0      https://doi.org/10.1016/j.polymer.2020.123034
# 1       https://doi.org/10.1021/acs.macromol.0c01784
# 2   https://doi.org/10.1016/j.jnoncrysol.2006.01.131
# 3                  https://doi.org/10.1021/la015712x
# 4             https://doi.org/10.1002/adfm.200400064
# 5                  https://doi.org/10.1021/ja306430k
# 6                  https://doi.org/10.1021/ja072929q
# 7                   https://doi.org/10.1038/nmat2232
# 8             https://doi.org/10.1021/acsapm.5c01168
# 9                  https://doi.org/10.1021/ma4023185
# 10    https://doi.org/10.1016/j.ijadhadh.2020.102585
# 11         https://doi.org/10.1016/j.eml.2025.102293
# 12            https://doi.org/10.1002/adfm.202311457
# 13              https://doi.org/10.3390/ijms23137164
# 14                 https://doi.org/10.1115/1.4068595
# 15    https://doi.org/10.12968/jowc.2020.29.sup3c.s1
# 16      https://doi.org/10.12968/jowc.2023.32.10.665
# 17                 https://doi.org/10.1021/ac2011608
# 18     https://doi.org/10.1016/j.polymer.2019.02.052
# 19      https://doi.org/10.1016/j.colcom.2025.100837
# 20              https://doi.org/10.1038/jid.2012.429
# 21                 https://doi.org/10.2144/000112089
# 22               https://doi.org/10.1385/mb:16:2:127
# 23            https://doi.org/10.1126/sciadv.aay0044
# 24        https://doi.org/10.1038/s41467-024-48146-y
# 25     https://doi.org/10.1016/j.heliyon.2024.e32184
# 26         https://doi.org/10.1017/s1551929521001553
# 27                  https://doi.org/10.1038/nmeth818
# 28                https://doi.org/10.1039/d4nh00395k
# 29            https://doi.org/10.1002/anie.201101005
# 30            https://doi.org/10.1002/smll.201101637
# 31     https://doi.org/10.1016/s0963-9969(01)00117-x
# 32            https://doi.org/10.1002/smll.201503396
# 33            https://doi.org/10.1002/marc.202300304
# 34            https://doi.org/10.1002/macp.202300230
# 35     https://doi.org/10.1002/14356007.a11_279.pub2
# 36                 https://doi.org/10.1021/jp203703e
# 37      https://doi.org/10.1016/j.molliq.2024.125424
# 38                 https://doi.org/10.1115/1.4045298
# 39         https://doi.org/10.1007/s10853-007-2416-x
# 40           https://doi.org/10.1021/acs.cgd.9b00052
# 41     https://doi.org/10.1088/0034-4885/79/4/046601
# 42                 https://doi.org/10.1021/la950887q
# 43         https://doi.org/10.1080/00218467208072199
# 44       https://doi.org/10.1088/0022-3727/11/14/011
# 45                https://doi.org/10.1039/c5sm00260e
# 46         https://doi.org/10.1007/s10704-016-0171-1
# 47                   https://doi.org/10.1038/nmat966
# 48      https://doi.org/10.1021/acs.macromol.6b00121
# 49                 https://doi.org/10.1021/ma202600b
# 50                 https://doi.org/10.1021/ma9806155
# 51                 https://doi.org/10.1021/ma902035p
# 52        https://doi.org/10.1038/s41467-021-26773-z
# 53            https://doi.org/10.1098/rsta.2021.0110
# 54                https://doi.org/10.1039/d4cs01193g

# %%
def _safe_first(x):
    return (x[0] if isinstance(x, list) and x else None)

def _acs_author_list(authors):
    """
    ACS-ish author string: 'Last, F. M.; Last, F. M.; ...'
    """
    if not authors:
        return None
    out = []
    for a in authors:
        family = a.get("family")
        given = a.get("given")
        if family and given:
            parts = re.split(r"[\s\-]+", given.strip())
            initials = " ".join([p[0] + "." for p in parts if p])
            out.append(f"{family}, {initials}")
        elif family:
            out.append(f"{family}")
    return "; ".join(out) if out else None

def crossref_fetch_work(doi: str, timeout=20):
    if not doi:
        return None
    url = f"https://api.crossref.org/works/{doi}"
    headers = {"User-Agent": "kilbreths-pig/0.1 (mailto:YOUR_EMAIL_HERE)"}
    r = requests.get(url, headers=headers, timeout=timeout)
    if r.status_code != 200:
        return None
    return (r.json().get("message") or {})

def crossref_to_df_row(ref_id: int, doi: str, msg: dict):
    if not msg:
        return {
            "ref_id": ref_id,
            "doi": doi,
            "ok": False
        }

    issued = (msg.get("issued", {}) or {}).get("date-parts", [[None]])
    year = issued[0][0] if issued and issued[0] else None

    return {
        "ref_id": ref_id,
        "doi": doi,
        "doi_url": f"https://doi.org/{doi}" if doi else None,
        "title": _safe_first(msg.get("title")),
        "authors": _acs_author_list(msg.get("author")),
        "journal": _safe_first(msg.get("container-title")),
        "year": year,
        "volume": msg.get("volume"),
        "issue": msg.get("issue"),
        "pages": msg.get("page"),
        "publisher": msg.get("publisher"),
        "type": msg.get("type"),
        "ok": True
    }

def build_df_doi_from_df_original(df_original: pd.DataFrame, sleep_s=0.15) -> pd.DataFrame:
    rows = []
    for _, r in df_original.iterrows():
        ref_id = int(r["ref_id"])
        doi = r.get("doi_final")
        if not isinstance(doi, str) or not doi:
            rows.append({"ref_id": ref_id, "doi": None, "ok": False})
            continue

        msg = crossref_fetch_work(doi)
        rows.append(crossref_to_df_row(ref_id, doi, msg))
        time.sleep(sleep_s)

    return pd.DataFrame(rows)

# %%
df_doi = build_df_doi_from_df_original(df_original, sleep_s=0.2)

# %%
df_join = df_original.merge(
    df_doi[["ref_id","title","authors","journal","year","volume","issue","pages","doi"]],
    left_on="ref_id",
    right_on="ref_id",
    how="left",
    suffixes=("_orig","_doi")
)

# %%
df_DOI = add_iso4_columns(df_doi)

# %%
def score_row(raw, title, authors, journal, journal_iso4, year):
    s = []

    if title:
        s.append(0.45 * fuzz.token_set_ratio(raw, title))

    if authors:
        s.append(0.25 * fuzz.partial_ratio(raw, authors))

    # --- journal logic ---
    journal_scores = []
    if journal:
        journal_scores.append(fuzz.partial_ratio(raw, journal))
    if journal_iso4:
        journal_scores.append(fuzz.partial_ratio(raw, journal_iso4))

    if journal_scores:
        s.append(0.20 * max(journal_scores))

    if year:
        s.append(0.10 * fuzz.partial_ratio(raw, str(year)))

    return sum(s) / (0.45 + 0.25 + 0.20 + 0.10)


assert df_join["ref_id"].is_unique
assert df_DOI["ref_id"].is_unique

df_join = df_join.merge(
    df_DOI[["ref_id", "journal_iso4"]],
    on="ref_id",
    how="left",
    validate="one_to_one",
    suffixes=("", "_doi"),
)

# If df_join already had journal_iso4, prefer the DOI-derived one when present
if "journal_iso4_doi" in df_join.columns:
    df_join["journal_iso4"] = df_join["journal_iso4_doi"].combine_first(df_join.get("journal_iso4"))
    df_join.drop(columns=["journal_iso4_doi"], inplace=True)


df_join["match_score"] = df_join.apply(
    lambda r: score_row(
        r["raw"],
        r["title"],
        r["authors"],
        r["journal"],
        r["journal_iso4"],
        r["year"],
    ),
    axis=1
)

df_join["match_score"].describe()
# Out:
# count     55.000000
# mean      86.957720
# std        9.739525
# min       61.882560
# 25%       80.209898
# 50%       87.045455
# 75%       96.465102
# max      100.000000
# Name: match_score, dtype: float64

# %%
df_join.sort_values("match_score").head(10)[
    ["ref_id","match_score","doi","journal","year","title","raw"]
]
# Out:
#     ref_id  match_score                               doi  \
# 53      54    61.882560            10.1098/rsta.2021.0110
# 7        8    67.211034                  10.1038/nmat2232
# 15      16    70.180723    10.12968/jowc.2020.29.sup3c.s1
# 45      46    72.137509                10.1039/c5sm00260e
# 23      24    73.423707            10.1126/sciadv.aay0044
# 24      25    74.184953        10.1038/s41467-024-48146-y
# 16      17    75.054797      10.12968/jowc.2023.32.10.665
# 2        3    75.244405  10.1016/j.jnoncrysol.2006.01.131
# 39      40    76.315789         10.1007/s10853-007-2416-x
# 27      28    77.142857                  10.1038/nmeth818
#
#                                               journal  year  \
# 53  Philosophical Transactions of the Royal Societ...  2022
# 7                                    Nature Materials  2008
# 15                              Journal of Wound Care  2020
# 45                                        Soft Matter  2015
# 23                                   Science Advances  2019
# 24                              Nature Communications  2024
# 16                              Journal of Wound Care  2023
# 2                   Journal of Non-Crystalline Solids  2006
# 39                       Journal of Materials Science  2008
# 27                                     Nature Methods  2005
#
#                                                 title  \
# 53  Super-resolution microscopy: a brief history a...
# 7        Water-soluble organo-silica hybrid nanowires
# 15  Overlooked and underestimated: medical adhesiv...
# 45  Rate-dependent elastic hysteresis during the p...
# 23  FeSe quantum dots for in vivo multiphoton biom...
# 24  A modular framework for multi-scale tissue ima...
# 16  A temperature-sensitive, high-adhesion medical...
# 2   On the crystallization behavior of frustrated ...
# 39                      Ageing of two petroleum waxes
# 27                  Deep tissue two-photon microscopy
#
#                                                   raw
# 53  Prakash, K.; Diederich, B.; Heintzmann, R.; Sc...
# 7   Yuan, J.; Xu, Y.; Walther, A.; Bolisetty, S.; ...
# 15  Fumarola, S.; Allaway, R.; Callaghan, R.; Coll...
# 45  Villey, R.; Creton, C.; Cortet, P.-P.; Dalbe, ...
# 23  Kwon, J.; Jun, S. W.; Choi, S. I.; Mao, X.; Ki...
# 24  Cauzzo, S.; Bruno, E.; Boulet, D.; Nazac, P.; ...
# 16  Swanson, S.; Luu, V.; Smith, R.; Gross, A.; Tu...
# 2   Hempel, E.; Budde, H.; Höring, S.; Beiner, M. ...
# 39  Petersson, M.; Gustafson, I.; Stading, M. Agei...
# 27  Helmchen, F.; Denk, W. Deep Tissue Two-Photon ...

# %%
def _norm_ws(s: str) -> str:
    return re.sub(r"\s+", " ", (s or "").strip())

def _fix_pages(p: str) -> str:
    if not p:
        return ""
    # normalize hyphen variants and remove spaces around dash
    p = p.replace("−", "-").replace("–", "-")
    p = re.sub(r"\s*-\s*", "-", p)
    return p

def format_acs_ref(row) -> str:
    """
    ACS-ish format (not perfect abbreviations):
      (n) Authors. Title. Journal Year, Volume (Issue), Pages. DOI: xxxx.
    """
    ref_id = row.get("ref_id")
    authors = _norm_ws(row.get("authors") or "")
    title = _norm_ws(row.get("title") or "")
    journal = _norm_ws(row.get("journal_iso4") or "")
    year = row.get("year") or ""
    volume = _norm_ws(str(row.get("volume") or ""))
    issue = _norm_ws(str(row.get("issue") or ""))
    pages = _fix_pages(_norm_ws(str(row.get("pages") or "")))
    doi = _norm_ws(row.get("doi") or "")

    bits = []
    if authors:
        bits.append(f"{authors}.")
    if title:
        bits.append(f"{title}.")
    if journal:
        # Journal block: Journal Year, Volume (Issue), Pages.
        j = journal
        y = str(year) if year else ""
        v = volume
        iss = f" ({issue})" if issue and issue.lower() != "none" else ""
        pg = f", {pages}" if pages else ""

        # Build "Journal Year, Volume (Issue), Pages."
        # Handle missing volume gracefully.
        core = j
        if y:
            core += f" {y}"
        if v:
            core += f", {v}{iss}{pg}."
        else:
            core += f"."
        bits.append(core)

    if doi:
        bits.append(f"DOI: {doi}.")

    inner = " ".join(bits).strip()
    return f"({ref_id}) {inner}".strip()

def write_acs_bibliography_docx(df_doi, out_path="acs_bibliography.docx"):
    df = df_doi.sort_values("ref_id").copy()
    doc = Document()
    doc.add_heading("ACS-Style Bibliography (from DOI metadata)", level=1)

    for _, r in df.iterrows():
        doc.add_paragraph(format_acs_ref(r))

    doc.save(out_path)
    return out_path

def write_acs_bibliography_txt(df_doi, out_path="acs_bibliography.txt"):
    df = df_doi.sort_values("ref_id").copy()
    lines = [format_acs_ref(r) for _, r in df.iterrows()]
    with open(out_path, "w", encoding="utf-8") as f:
        f.write("\n\n".join(lines) + "\n")
    return out_path

# Generate outputs
docx_path = write_acs_bibliography_docx(df_join, "acs_complete_bibliography.docx")
txt_path  = write_acs_bibliography_txt(df_join, "acs_complete_bibliography.txt")

docx_path, txt_path
# Out:
# ('acs_complete_bibliography.docx', 'acs_complete_bibliography.txt')

# %%
thresholds = PigThresholds(happy=50.0, maybe=35.0)

# df_compare (or df_join) must include: ref_id, match_score
# Optional: title, doi_url_final/doi_url, raw
build_acs_report(
    df_compare=df_join,  # or df_join
    out_pdf="Kilbreths_Pig_ACS_Report.pdf",
    article_title=ARTICLE_TITLE,
    source_pdf="test.pdf",
    thresholds=thresholds,
    logo_path="logo.png",
    yes_icon="yes.png",
    maybe_icon="maybe.png",
    no_icon="no.png",
)
# Out:
# 'Kilbreths_Pig_ACS_Report.pdf'

# %%
df_DOI

# %%
df_join = df_original.merge(
    df_DOI[
        [
            "ref_id",
            "title",
            "authors",
            "journal",
            "journal_full",
            "journal_iso4",
            "journal_preferred",
            "year",
            "volume",
            "issue",
            "pages",
            "doi",
        ]
    ],
    on="ref_id",
    how="left",
    suffixes=("_orig", "_doi"),
)

# %%
tmp = df_join.apply(
    lambda row: best_journal_score(
        obs_journal=row["journal_orig"],
        doi_journal_full=row["journal_full"],
        doi_journal_iso4=row["journal_iso4"],
        score_fn=fuzz.token_set_ratio,
    ),
    axis=1
)

df_join["journal_match_score"] = [t[0] for t in tmp]
df_join["journal_match_variant"] = [t[1] for t in tmp]

# %%
[c for c in df_join.columns if "journal" in c.lower()]

# %%
[c for c in df_original.columns if "journal" in c.lower() or "source" in c.lower() or "container" in c.lower()]

# %%
[c for c in df_original.columns if "raw" in c.lower() or "ref" in c.lower() or "text" in c.lower()]

# %%
df_original["journal_obs"] = df_original["raw"].apply(extract_journal_from_acs_raw)

# %%
df_join = df_original.merge(
    df_DOI[
        [
            "ref_id",
            "journal",
            "journal_full",
            "journal_iso4",
            "journal_preferred",
            "doi",
            "title",
            "authors",
            "year",
            "volume",
            "issue",
            "pages",
        ]
    ],
    on="ref_id",
    how="left",
    suffixes=("_orig", "_doi")
)

# %%
# 1) Repair journal_obs using raw (row-wise)
df_join["journal_obs"] = df_join.apply(
    lambda r: clean_journal_obs(r.get("journal_obs",""), r.get("raw","")),
    axis=1
)

# 2) Recompute journal matching scores
tmp = df_join.apply(
    lambda r: best_journal_score(
        obs_journal=r.get("journal_obs",""),
        doi_journal_full=r.get("journal_full",""),
        doi_journal_iso4=r.get("journal_iso4",""),
        score_fn=fuzz.token_set_ratio,
    ),
    axis=1
)

df_join["journal_match_score"]   = [t[0] for t in tmp]
df_join["journal_match_variant"] = [t[1] for t in tmp]

# 3) Inspect the problem row
df_join.loc[df_join["ref_id"] == 23,
            ["ref_id","journal_obs","journal_full","journal_iso4",
             "journal_preferred","journal_match_score","journal_match_variant"]]

# %%
df_join

# %%
import importlib
import journal_title.journal_from_raw as jfr

importlib.reload(jfr)

# Rebind the names in *this notebook's* namespace
clean_journal_obs = jfr.clean_journal_obs
extract_journal_from_acs_raw = jfr.extract_journal_from_acs_raw

# sanity check
import inspect
print("NOW LOCAL:", inspect.signature(clean_journal_obs))

# %%
obs = clean_journal_obs(row.get("journal_obs",""), row.get("raw",""))

# %%
df_join["journal_obs"] = df_join.apply(
    lambda r: clean_journal_obs(
        r.get("journal_obs",""),
        r.get("raw",""),
        r.get("journal_full",""),
        r.get("journal_iso4",""),
    ),
    axis=1,
)

df_join["journal_match_score"]   = [t[0] for t in tmp]
df_join["journal_match_variant"] = [t[1] for t in tmp]

# 3) Inspect the problem row
df_join.loc[df_join["ref_id"] == 23,
            ["ref_id","journal_obs","journal_full","journal_iso4",
             "journal_preferred","journal_match_score","journal_match_variant"]]

# %%
import inspect
from journal_title import journal_from_raw

inspect.signature(journal_from_raw.clean_journal_obs)
inspect.getsource(journal_from_raw.clean_journal_obs)

# %%
import inspect
import journal_title.journal_from_raw as jfr

print("MODULE VERSION:", inspect.signature(jfr.clean_journal_obs))
print("LOCAL  VERSION:", inspect.signature(clean_journal_obs))
print("MODULE FILE:", jfr.__file__)
print("LOCAL  FROM:", inspect.getmodule(clean_journal_obs).__file__)
